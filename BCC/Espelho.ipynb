# %%
A = int(input())
B = int(input())
MA = A//1000
MB = B//1000
CA = A%1000//100
CB = B%1000//100
DA = A%100//10
DB = B%100//10
UA = A%10
UB = B%10
if MA == UB and CA == DB and DA == CB and UA == MB:
  print("espelho")
else:
  print("nao espelho")
# Out:
# 9999
# 8888
# nao espelho
