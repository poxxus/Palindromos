# %%
a = int(input())
if a/100000>=1:
  print("6")
elif a/10000>=1:
  print("5")
elif a/1000>=1:
  print("4")
elif a/100>=1:
  print("3")
elif a/10>=1:
  print("2")
else:
  print("1")
# Out:
# 5050
# 4
