# %%
dia, mes, ano = input(), input(), input()
dia, mes, ano = [int(x) for x in [dia, mes, ano]]
if ano%4==0 and ano%100!=0 or ano%400==0:
  if mes in (1,3,5,7,8,10,12) and dia<=31:
    print("DATA VALIDA")
  if mes==2 and dia<=29:
    print("DATA VALIDA")
  elif mes in (4,6,9,11) and dia<=30:
    print("DATA VALIDA")
  elif mes in (1,3,5,7,8,10,12) and dia>31 or mes in (4,6,9,11) and dia>30 or mes==2 and dia>29:
    print("DATA INVALIDA") 
else:
  if mes in (1,3,5,7,8,10,12) and dia<=31:
    print("DATA VALIDA")
  elif mes==2 and dia<=28:
    print("DATA VALIDA")
  if mes in (4,6,9,11) and dia<=30:
    print("DATA VALIDA")
  elif mes in (1,3,5,7,8,10,12) and dia>31 or mes in (4,6,9,11) and dia>30 or mes==2 and dia>28:
    print("DATA INVALIDA")
# Out:
# 1
# 2
# 2001
# DATA VALIDA
