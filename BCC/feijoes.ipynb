# %%
a,b,c,d = input(), input(), input(), input()
a,b,c,d = [int(x) for x in [a,b,c,d]]
if a==1:
  print("1")
elif b==1:
  print("2")
elif c==1:
  print("3")
elif d==1:
  print("4")
# Out:
# 0
# 0
# 1
# 0
# 3
