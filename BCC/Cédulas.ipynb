# %%
N = int(input())
C100 = N//100   # Cédulas de 100
N2 = N%100
C50 = N2//50    # Cédulas de 50
N3 = N2%50
C20 = N3//20    # Cédulas de 20
N4 = N3%20
C10 = N4//10    # Cédulas de 10
N5 = N4%10
C5 = N5//5    # Cédulas de 5
N6 = N5%5
C2 = N6//2    # Cédulas de 2
N7 = N6%2
C1 = N7//1    # Cédulas de 1
print("R$",N,".00", sep ='')
print(C100,"nota(s) de R$100.00")
print(C50,"nota(s) de R$50.00")
print(C20,"nota(s) de R$20.00")
print(C10,"nota(s) de R$10.00")
print(C5,"nota(s) de R$5.00")
print(C2,"nota(s) de R$2.00")
print(C1,"nota(s) de R$1.00")
# Out:
# 520
# R$520.00
# 5 nota(s) de R$100.00
# 0 nota(s) de R$50.00
# 1 nota(s) de R$20.00
# 0 nota(s) de R$10.00
# 0 nota(s) de R$5.00
# 0 nota(s) de R$2.00
# 0 nota(s) de R$1.00
