# %%
a,b,c = input(), input(), input()
a,b,c = [int(x) for x in [a,b,c]]
if a<=b<=c:
  print(a,b,c)
elif b<=a<=c:
  print(b,a,c)
elif c<=a<=b:
  print(c,a,b)
elif c<=b<=a:
  print(c,b,a)
elif  a<=c<=b:
  print(a,c,b)
elif b<=c<=a:
  print(b,c,a)
